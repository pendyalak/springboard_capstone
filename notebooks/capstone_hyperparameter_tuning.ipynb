# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spooky-author-identification/train.zip
# /kaggle/input/spooky-author-identification/test.zip
# /kaggle/input/spooky-author-identification/sample_submission.zip
# /kaggle/input/capstone-karthik/new_train.csv

# %%
# !pip install -q --upgrade pip

## installing the latest transformers version from pip
# !pip install --use-feature=2020-resolver -q transformers==3.0.2
import transformers

## installing Google Translator package
# !pip install -q googletrans
# Out:
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.

# %%
import gc
import os
import random
import transformers
import warnings

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras.backend as K

from googletrans import Translator
from pathlib import Path
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from transformers import AutoTokenizer, TFAutoModel

print(f"TensorFlow version: {tf.__version__}")
print(f"Transformers version: {transformers.__version__}")

warnings.filterwarnings("ignore")
# Out:
# TensorFlow version: 2.2.0
# Transformers version: 3.0.2

# %%
class Configuration():
    """
    All configuration for running an experiment
    """
    def __init__(
        self,
        model_name,
        truncation = True,
        translation = True,
        max_length = 64,
        padding = True,
        batch_size = 128,
        epochs = 5,
        learning_rate = 1e-5,
        metrics = ["sparse_categorical_accuracy"],
        verbose = 1,
        train_splits = 5,
        accelerator = "TPU",
        myluckynumber = 13
    ):
        # seed and accelerator
        self.SEED = myluckynumber
        self.ACCELERATOR = accelerator

        # paths
        self.PATH_TRAIN = Path("../input/capstone-karthik/new_train.csv")
        self.PATH_TEST  = Path("../input/spooky-author-identification/test.zip")

        # splits
        self.TRAIN_SPLITS = train_splits

        
        # model configuration
        self.MODEL_NAME = model_name
        # self.TRANSLATION = translation
        self.TOKENIZER = AutoTokenizer.from_pretrained(self.MODEL_NAME)

        # model hyperparameters
        self.MAX_LENGTH = max_length
        self.PAD_TO_MAX_LENGTH = padding
        self.BATCH_SIZE = batch_size
        self.EPOCHS = epochs
        self.LEARNING_RATE = learning_rate
        self.METRICS = metrics
        self.VERBOSE = verbose
        
        # initializing accelerator
        self.initialize_accelerator()

    def initialize_accelerator(self):
        """
        Initializing accelerator
        """
        # checking TPU first
        if self.ACCELERATOR == "TPU":
            print("Connecting to TPU")
            try:
                tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
                print(f"Running on TPU {tpu.master()}")
            except ValueError:
                print("Could not connect to TPU")
                tpu = None

            if tpu:
                try:
                    print("Initializing TPU")
                    tf.config.experimental_connect_to_cluster(tpu)
                    tf.tpu.experimental.initialize_tpu_system(tpu)
                    self.strategy = tf.distribute.experimental.TPUStrategy(tpu)
                    self.tpu = tpu
                    print("TPU initialized")
                except _:
                    print("Failed to initialize TPU")
            else:
                print("Unable to initialize TPU")
                self.ACCELERATOR = "GPU"

        # default for CPU and GPU
        if self.ACCELERATOR != "TPU":
            print("Using default strategy for CPU and single GPU")
            self.strategy = tf.distribute.get_strategy()

        # checking GPUs
        if self.ACCELERATOR == "GPU":
            print(f"GPUs Available: {len(tf.config.experimental.list_physical_devices('GPU'))}")

        # defining replicas
        self.AUTO = tf.data.experimental.AUTOTUNE
        self.REPLICAS = self.strategy.num_replicas_in_sync
        print(f"REPLICAS: {self.REPLICAS}")

# %%
def encode_text(df, tokenizer, max_len, padding):
    """
    Preprocessing textual data into encoded tokens.
    """
    text = df["text"].values.tolist()

    # encoding text using tokenizer of the model
    text_encoded = tokenizer.batch_encode_plus(
        text,
        pad_to_max_length = padding,
        max_length = max_len
    )

    return text_encoded


def get_tf_dataset(X, y, auto, labelled = True, repeat = False, shuffle = False, batch_size = 128):
    """
    Creating tf.data.Dataset for TPU.
    """
    if labelled:
        ds = (tf.data.Dataset.from_tensor_slices((X["input_ids"], y)))
    else:
        ds = (tf.data.Dataset.from_tensor_slices(X["input_ids"]))

    if repeat:
        ds = ds.repeat()

    if shuffle:
        ds = ds.shuffle(2048)

    ds = ds.batch(batch_size)
    ds = ds.prefetch(auto)

    return ds

# %%
def build_model(model_name, max_len, learning_rate, metrics):
    """
    Building the Deep Learning architecture
    """
    # defining encoded inputs
    input_ids = Input(shape = (max_len,), dtype = tf.int32, name = "input_ids")
    
    # defining transformer model embeddings
    transformer_model = TFAutoModel.from_pretrained(model_name)
    transformer_embeddings = transformer_model(input_ids)[0]

    # defining output layer
    output_values = Dense(3, activation = "softmax")(transformer_embeddings[:, 0, :])

    # defining model
    model = Model(inputs = input_ids, outputs = output_values)
    opt = Adam(learning_rate = learning_rate)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)
    metrics = metrics

    model.compile(optimizer = opt, loss = loss, metrics = metrics)

    return model

# %%
def run_model(config):
    """
    Running the model
    """
    ## reading data
    df_train = pd.read_csv(config.PATH_TRAIN)
    df_test = pd.read_csv(config.PATH_TEST)

     # stratified K-fold on language and label
    skf = StratifiedKFold(n_splits = config.TRAIN_SPLITS, shuffle = True, random_state = config.SEED)

    # initializing predictions
    preds_oof = np.zeros((df_train.shape[0], 3))
    preds_test = np.zeros((df_test.shape[0], 3))
    acc_oof = []

    # iterating over folds
    for (fold, (train_index, valid_index)) in enumerate(skf.split(df_train, df_train.author)):
        # initializing TPU
        if config.ACCELERATOR == "TPU":
            if config.tpu:
                config.initialize_accelerator()

        # building model
        K.clear_session()
        with config.strategy.scope():
            model = build_model(config.MODEL_NAME, config.MAX_LENGTH, config.LEARNING_RATE, config.METRICS)
            if fold == 0:
                print(model.summary())

        print("\n")
        print("#" * 19)
        print(f"##### Fold: {fold + 1} #####")
        print("#" * 19)

        # splitting data into training and validation
        X_train = df_train.iloc[train_index]
        X_valid = df_train.iloc[valid_index]

        y_train = X_train.author.values
        y_valid = X_valid.author.values

        print("\nTokenizing")

        # encoding text data using tokenizer
        X_train_encoded = encode_text(df = X_train, tokenizer = config.TOKENIZER, max_len = config.MAX_LENGTH, padding = config.PAD_TO_MAX_LENGTH)
        X_valid_encoded = encode_text(df = X_valid, tokenizer = config.TOKENIZER, max_len = config.MAX_LENGTH, padding = config.PAD_TO_MAX_LENGTH)

        # creating TF Dataset
        ds_train = get_tf_dataset(X_train_encoded, y_train, config.AUTO, repeat = True, shuffle = True, batch_size = config.BATCH_SIZE * config.REPLICAS)
        ds_valid = get_tf_dataset(X_valid_encoded, y_valid, config.AUTO, batch_size = config.BATCH_SIZE * config.REPLICAS * 4)

        n_train = X_train.shape[0]

        if fold == 0:
            X_test_encoded = encode_text(df = df_test, tokenizer = config.TOKENIZER, max_len = config.MAX_LENGTH, padding = config.PAD_TO_MAX_LENGTH)

        # saving model at best accuracy epoch
        sv = tf.keras.callbacks.ModelCheckpoint(
            "model.h5",
            monitor = "val_sparse_categorical_accuracy",
            verbose = 0,
            save_best_only = True,
            save_weights_only = True,
            mode = "max",
            save_freq = "epoch"
        )

        print("\nTraining")

        # training model
        model_history = model.fit(
            ds_train,
            epochs = config.EPOCHS,
            callbacks = [sv],
            steps_per_epoch = n_train / config.BATCH_SIZE // config.REPLICAS,
            validation_data = ds_valid,
            verbose = config.VERBOSE
        )

        print("\nValidating")

        # scoring validation data
        model.load_weights("model.h5")
        ds_valid = get_tf_dataset(X_valid_encoded, -1, config.AUTO, labelled = False, batch_size = config.BATCH_SIZE * config.REPLICAS * 4)

        preds_valid = model.predict(ds_valid, verbose = config.VERBOSE)
        acc = accuracy_score(y_valid, np.argmax(preds_valid, axis = 1))

        preds_oof[valid_index] = preds_valid
        acc_oof.append(acc)

        print("\nInferencing")

        # scoring test data
        ds_test = get_tf_dataset(X_test_encoded, -1, config.AUTO, labelled = False, batch_size = config.BATCH_SIZE * config.REPLICAS * 4)
        preds_test += model.predict(ds_test, verbose = config.VERBOSE) / config.TRAIN_SPLITS

        print(f"\nFold {fold + 1} Accuracy: {round(acc, 4)}\n")

        g = gc.collect()

    # overall CV score and standard deviation
    print(f"\nCV Mean Accuracy: {round(np.mean(acc_oof), 4)}")
    print(f"CV StdDev Accuracy: {round(np.std(acc_oof), 4)}\n")

    return preds_oof, preds_test

# %%
# Final Model: XLM Roberta Large
# config_1 = Configuration("jplu/tf-xlm-roberta-large", translation = False, max_length = 84, batch_size = 64, epochs = 16, train_splits = 4)
# preds_train_1, preds_test_1 = run_model(config_1)
# Out:
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=3271420488.0, style=ProgressStyle(descr…
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 84)]              0
# _________________________________________________________________
# tf_roberta_model (TFRobertaM ((None, 84, 1024), (None, 559890432
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 1024)]            0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 3075
# =================================================================
# Total params: 559,893,507
# Trainable params: 559,893,507
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ###################
# ##### Fold: 1 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 106s 4s/step - sparse_categorical_accuracy: 0.4190 - loss: 1.0730 - val_sparse_categorical_accuracy: 0.4784 - val_loss: 1.0289
# Epoch 2/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.5869 - loss: 0.9586 - val_sparse_categorical_accuracy: 0.6656 - val_loss: 0.8772
# Epoch 3/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.7114 - loss: 0.8348 - val_sparse_categorical_accuracy: 0.7381 - val_loss: 0.8085
# Epoch 4/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.7583 - loss: 0.7877 - val_sparse_categorical_accuracy: 0.7769 - val_loss: 0.7707
# Epoch 5/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.7882 - loss: 0.7579 - val_sparse_categorical_accuracy: 0.8008 - val_loss: 0.7455
# Epoch 6/16
# 28/28 [==============================] - 21s 748ms/step - sparse_categorical_accuracy: 0.8079 - loss: 0.7372 - val_sparse_categorical_accuracy: 0.7839 - val_loss: 0.7594
# Epoch 7/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8361 - loss: 0.7129 - val_sparse_categorical_accuracy: 0.8172 - val_loss: 0.7289
# Epoch 8/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8463 - loss: 0.7035 - val_sparse_categorical_accuracy: 0.8182 - val_loss: 0.7284
# Epoch 9/16
# 28/28 [==============================] - 21s 746ms/step - sparse_categorical_accuracy: 0.8513 - loss: 0.6978 - val_sparse_categorical_accuracy: 0.8159 - val_loss: 0.7309
# Epoch 10/16
# 28/28 [==============================] - 21s 744ms/step - sparse_categorical_accuracy: 0.8728 - loss: 0.6771 - val_sparse_categorical_accuracy: 0.8157 - val_loss: 0.7296
# Epoch 11/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8825 - loss: 0.6683 - val_sparse_categorical_accuracy: 0.8253 - val_loss: 0.7204
# Epoch 12/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8971 - loss: 0.6540 - val_sparse_categorical_accuracy: 0.8374 - val_loss: 0.7086
# Epoch 13/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8978 - loss: 0.6532 - val_sparse_categorical_accuracy: 0.8388 - val_loss: 0.7088
# Epoch 14/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.9048 - loss: 0.6462 - val_sparse_categorical_accuracy: 0.8429 - val_loss: 0.7053
# Epoch 15/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.9175 - loss: 0.6354 - val_sparse_categorical_accuracy: 0.8484 - val_loss: 0.6981
# Epoch 16/16
# 28/28 [==============================] - 21s 742ms/step - sparse_categorical_accuracy: 0.9261 - loss: 0.6249 - val_sparse_categorical_accuracy: 0.8460 - val_loss: 0.7013
#
# Validating
# 3/3 [==============================] - 32s 11s/step
#
# Inferencing
# 5/5 [==============================] - 30s 6s/step
#
# Fold 1 Accuracy: 0.8484
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 2 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 71s 3s/step - sparse_categorical_accuracy: 0.4510 - loss: 1.0570 - val_sparse_categorical_accuracy: 0.6396 - val_loss: 0.9283
# Epoch 2/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.6662 - loss: 0.8780 - val_sparse_categorical_accuracy: 0.7526 - val_loss: 0.7900
# Epoch 3/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.7735 - loss: 0.7745 - val_sparse_categorical_accuracy: 0.7882 - val_loss: 0.7565
# Epoch 4/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.8033 - loss: 0.7419 - val_sparse_categorical_accuracy: 0.7969 - val_loss: 0.7480
# Epoch 5/16
# 28/28 [==============================] - 21s 742ms/step - sparse_categorical_accuracy: 0.8239 - loss: 0.7235 - val_sparse_categorical_accuracy: 0.7953 - val_loss: 0.7524
# Epoch 6/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8463 - loss: 0.7030 - val_sparse_categorical_accuracy: 0.8059 - val_loss: 0.7395
# Epoch 7/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.8665 - loss: 0.6834 - val_sparse_categorical_accuracy: 0.8245 - val_loss: 0.7214
# Epoch 8/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8676 - loss: 0.6816 - val_sparse_categorical_accuracy: 0.8257 - val_loss: 0.7217
# Epoch 9/16
# 28/28 [==============================] - 21s 746ms/step - sparse_categorical_accuracy: 0.8714 - loss: 0.6773 - val_sparse_categorical_accuracy: 0.8092 - val_loss: 0.7344
# Epoch 10/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8931 - loss: 0.6572 - val_sparse_categorical_accuracy: 0.8329 - val_loss: 0.7167
# Epoch 11/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8966 - loss: 0.6526 - val_sparse_categorical_accuracy: 0.8562 - val_loss: 0.6934
# Epoch 12/16
# 28/28 [==============================] - 21s 741ms/step - sparse_categorical_accuracy: 0.9053 - loss: 0.6443 - val_sparse_categorical_accuracy: 0.8543 - val_loss: 0.6942
# Epoch 13/16
# 28/28 [==============================] - 21s 745ms/step - sparse_categorical_accuracy: 0.9163 - loss: 0.6334 - val_sparse_categorical_accuracy: 0.8392 - val_loss: 0.7081
# Epoch 14/16
# 28/28 [==============================] - 21s 743ms/step - sparse_categorical_accuracy: 0.9167 - loss: 0.6340 - val_sparse_categorical_accuracy: 0.8394 - val_loss: 0.7057
# Epoch 15/16
# 28/28 [==============================] - 21s 743ms/step - sparse_categorical_accuracy: 0.9301 - loss: 0.6212 - val_sparse_categorical_accuracy: 0.8525 - val_loss: 0.6967
# Epoch 16/16
# 28/28 [==============================] - 21s 743ms/step - sparse_categorical_accuracy: 0.9363 - loss: 0.6149 - val_sparse_categorical_accuracy: 0.8525 - val_loss: 0.6956
#
# Validating
# 3/3 [==============================] - 13s 4s/step
#
# Inferencing
# 5/5 [==============================] - 15s 3s/step
#
# Fold 2 Accuracy: 0.8562
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 3 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 109s 4s/step - sparse_categorical_accuracy: 0.3988 - loss: 1.0885 - val_sparse_categorical_accuracy: 0.4035 - val_loss: 1.0768
# Epoch 2/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.5744 - loss: 0.9512 - val_sparse_categorical_accuracy: 0.7036 - val_loss: 0.8382
# Epoch 3/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.7524 - loss: 0.7925 - val_sparse_categorical_accuracy: 0.7661 - val_loss: 0.7779
# Epoch 4/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8059 - loss: 0.7399 - val_sparse_categorical_accuracy: 0.7935 - val_loss: 0.7535
# Epoch 5/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8276 - loss: 0.7201 - val_sparse_categorical_accuracy: 0.8022 - val_loss: 0.7443
# Epoch 6/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8521 - loss: 0.6973 - val_sparse_categorical_accuracy: 0.8278 - val_loss: 0.7188
# Epoch 7/16
# 28/28 [==============================] - 21s 747ms/step - sparse_categorical_accuracy: 0.8665 - loss: 0.6830 - val_sparse_categorical_accuracy: 0.8174 - val_loss: 0.7295
# Epoch 8/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8815 - loss: 0.6674 - val_sparse_categorical_accuracy: 0.8321 - val_loss: 0.7153
# Epoch 9/16
# 28/28 [==============================] - 21s 747ms/step - sparse_categorical_accuracy: 0.8966 - loss: 0.6541 - val_sparse_categorical_accuracy: 0.8264 - val_loss: 0.7203
# Epoch 10/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.9072 - loss: 0.6432 - val_sparse_categorical_accuracy: 0.8345 - val_loss: 0.7118
# Epoch 11/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.9107 - loss: 0.6406 - val_sparse_categorical_accuracy: 0.8376 - val_loss: 0.7088
# Epoch 12/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.9171 - loss: 0.6339 - val_sparse_categorical_accuracy: 0.8441 - val_loss: 0.7048
# Epoch 13/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.9191 - loss: 0.6319 - val_sparse_categorical_accuracy: 0.8445 - val_loss: 0.7029
# Epoch 14/16
# 28/28 [==============================] - 21s 751ms/step - sparse_categorical_accuracy: 0.9293 - loss: 0.6214 - val_sparse_categorical_accuracy: 0.8259 - val_loss: 0.7220
# Epoch 15/16
# 28/28 [==============================] - 21s 748ms/step - sparse_categorical_accuracy: 0.9277 - loss: 0.6238 - val_sparse_categorical_accuracy: 0.8390 - val_loss: 0.7096
# Epoch 16/16
# 28/28 [==============================] - 21s 750ms/step - sparse_categorical_accuracy: 0.9366 - loss: 0.6143 - val_sparse_categorical_accuracy: 0.8304 - val_loss: 0.7177
#
# Validating
# 3/3 [==============================] - 13s 4s/step
#
# Inferencing
# 5/5 [==============================] - 15s 3s/step
#
# Fold 3 Accuracy: 0.8445
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 4 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 83s 3s/step - sparse_categorical_accuracy: 0.3922 - loss: 1.0909 - val_sparse_categorical_accuracy: 0.3980 - val_loss: 1.0635
# Epoch 2/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.4289 - loss: 1.0686 - val_sparse_categorical_accuracy: 0.4587 - val_loss: 1.0510
# Epoch 3/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.5338 - loss: 0.9932 - val_sparse_categorical_accuracy: 0.6189 - val_loss: 0.9218
# Epoch 4/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.6583 - loss: 0.8817 - val_sparse_categorical_accuracy: 0.7154 - val_loss: 0.8275
# Epoch 5/16
# 28/28 [==============================] - 21s 749ms/step - sparse_categorical_accuracy: 0.7271 - loss: 0.8173 - val_sparse_categorical_accuracy: 0.5237 - val_loss: 1.0090
# Epoch 6/16
# 28/28 [==============================] - 32s 1s/step - sparse_categorical_accuracy: 0.7503 - loss: 0.7950 - val_sparse_categorical_accuracy: 0.7575 - val_loss: 0.7848
# Epoch 7/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.7855 - loss: 0.7607 - val_sparse_categorical_accuracy: 0.7630 - val_loss: 0.7789
# Epoch 8/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8182 - loss: 0.7305 - val_sparse_categorical_accuracy: 0.7828 - val_loss: 0.7599
# Epoch 9/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8276 - loss: 0.7211 - val_sparse_categorical_accuracy: 0.7953 - val_loss: 0.7517
# Epoch 10/16
# 28/28 [==============================] - 34s 1s/step - sparse_categorical_accuracy: 0.8442 - loss: 0.7051 - val_sparse_categorical_accuracy: 0.8159 - val_loss: 0.7302
# Epoch 11/16
# 28/28 [==============================] - 21s 745ms/step - sparse_categorical_accuracy: 0.8603 - loss: 0.6888 - val_sparse_categorical_accuracy: 0.7949 - val_loss: 0.7489
# Epoch 12/16
# 28/28 [==============================] - 21s 750ms/step - sparse_categorical_accuracy: 0.8546 - loss: 0.6938 - val_sparse_categorical_accuracy: 0.7822 - val_loss: 0.7612
# Epoch 13/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8783 - loss: 0.6726 - val_sparse_categorical_accuracy: 0.8214 - val_loss: 0.7242
# Epoch 14/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8841 - loss: 0.6648 - val_sparse_categorical_accuracy: 0.8265 - val_loss: 0.7199
# Epoch 15/16
# 28/28 [==============================] - 31s 1s/step - sparse_categorical_accuracy: 0.8971 - loss: 0.6541 - val_sparse_categorical_accuracy: 0.8386 - val_loss: 0.7091
# Epoch 16/16
# 28/28 [==============================] - 21s 749ms/step - sparse_categorical_accuracy: 0.9088 - loss: 0.6418 - val_sparse_categorical_accuracy: 0.8329 - val_loss: 0.7138
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 4 Accuracy: 0.8386
#
#
# CV Mean Accuracy: 0.8469
# CV StdDev Accuracy: 0.0064

# %%
# Model: Bert Base Cased
# config_2 = Configuration("bert-base-cased", max_length = 84, batch_size = 64, epochs = 16, train_splits = 4)
# preds_train_2, preds_test_2 = run_model(config_2)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=526681800.0, style=ProgressStyle(descri…
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 84)]              0
# _________________________________________________________________
# tf_bert_model (TFBertModel)  ((None, 84, 768), (None,  108310272
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 768)]             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 2307
# =================================================================
# Total params: 108,312,579
# Trainable params: 108,312,579
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ###################
# ##### Fold: 1 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 57s 2s/step - sparse_categorical_accuracy: 0.4107 - loss: 1.0810 - val_sparse_categorical_accuracy: 0.5430 - val_loss: 1.0360
# Epoch 2/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.6178 - loss: 0.9443 - val_sparse_categorical_accuracy: 0.7379 - val_loss: 0.8234
# Epoch 3/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.7518 - loss: 0.8014 - val_sparse_categorical_accuracy: 0.7871 - val_loss: 0.7625
# Epoch 4/16
# 28/28 [==============================] - 10s 343ms/step - sparse_categorical_accuracy: 0.8087 - loss: 0.7450 - val_sparse_categorical_accuracy: 0.8072 - val_loss: 0.7391
# Epoch 5/16
# 28/28 [==============================] - 10s 342ms/step - sparse_categorical_accuracy: 0.8371 - loss: 0.7151 - val_sparse_categorical_accuracy: 0.8225 - val_loss: 0.7225
# Epoch 6/16
# 28/28 [==============================] - 10s 366ms/step - sparse_categorical_accuracy: 0.8608 - loss: 0.6906 - val_sparse_categorical_accuracy: 0.8255 - val_loss: 0.7214
# Epoch 7/16
# 28/28 [==============================] - 11s 409ms/step - sparse_categorical_accuracy: 0.8824 - loss: 0.6726 - val_sparse_categorical_accuracy: 0.8362 - val_loss: 0.7111
# Epoch 8/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.8949 - loss: 0.6585 - val_sparse_categorical_accuracy: 0.8443 - val_loss: 0.7021
# Epoch 9/16
# 28/28 [==============================] - 7s 266ms/step - sparse_categorical_accuracy: 0.9052 - loss: 0.6469 - val_sparse_categorical_accuracy: 0.8398 - val_loss: 0.7062
# Epoch 10/16
# 28/28 [==============================] - 10s 350ms/step - sparse_categorical_accuracy: 0.9122 - loss: 0.6402 - val_sparse_categorical_accuracy: 0.8482 - val_loss: 0.6975
# Epoch 11/16
# 28/28 [==============================] - 7s 266ms/step - sparse_categorical_accuracy: 0.9238 - loss: 0.6287 - val_sparse_categorical_accuracy: 0.8419 - val_loss: 0.7031
# Epoch 12/16
# 28/28 [==============================] - 7s 264ms/step - sparse_categorical_accuracy: 0.9302 - loss: 0.6223 - val_sparse_categorical_accuracy: 0.8462 - val_loss: 0.7011
# Epoch 13/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.9395 - loss: 0.6140 - val_sparse_categorical_accuracy: 0.8513 - val_loss: 0.6937
# Epoch 14/16
# 28/28 [==============================] - 10s 351ms/step - sparse_categorical_accuracy: 0.9424 - loss: 0.6102 - val_sparse_categorical_accuracy: 0.8627 - val_loss: 0.6856
# Epoch 15/16
# 28/28 [==============================] - 7s 265ms/step - sparse_categorical_accuracy: 0.9471 - loss: 0.6065 - val_sparse_categorical_accuracy: 0.8515 - val_loss: 0.6945
# Epoch 16/16
# 28/28 [==============================] - 7s 266ms/step - sparse_categorical_accuracy: 0.9519 - loss: 0.6006 - val_sparse_categorical_accuracy: 0.8570 - val_loss: 0.6903
#
# Validating
# 3/3 [==============================] - 17s 6s/step
#
# Inferencing
# 5/5 [==============================] - 17s 3s/step
#
# Fold 1 Accuracy: 0.8627
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 2 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 38s 1s/step - sparse_categorical_accuracy: 0.5009 - loss: 1.0260 - val_sparse_categorical_accuracy: 0.6711 - val_loss: 0.8923
# Epoch 2/16
# 28/28 [==============================] - 10s 357ms/step - sparse_categorical_accuracy: 0.6994 - loss: 0.8501 - val_sparse_categorical_accuracy: 0.7469 - val_loss: 0.7987
# Epoch 3/16
# 28/28 [==============================] - 10s 362ms/step - sparse_categorical_accuracy: 0.7738 - loss: 0.7747 - val_sparse_categorical_accuracy: 0.7892 - val_loss: 0.7579
# Epoch 4/16
# 28/28 [==============================] - 10s 352ms/step - sparse_categorical_accuracy: 0.8195 - loss: 0.7307 - val_sparse_categorical_accuracy: 0.8025 - val_loss: 0.7415
# Epoch 5/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.8446 - loss: 0.7071 - val_sparse_categorical_accuracy: 0.8114 - val_loss: 0.7326
# Epoch 6/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.8643 - loss: 0.6875 - val_sparse_categorical_accuracy: 0.8243 - val_loss: 0.7208
# Epoch 7/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.8817 - loss: 0.6709 - val_sparse_categorical_accuracy: 0.8276 - val_loss: 0.7178
# Epoch 8/16
# 28/28 [==============================] - 8s 268ms/step - sparse_categorical_accuracy: 0.8977 - loss: 0.6552 - val_sparse_categorical_accuracy: 0.8231 - val_loss: 0.7210
# Epoch 9/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.9074 - loss: 0.6452 - val_sparse_categorical_accuracy: 0.8415 - val_loss: 0.7064
# Epoch 10/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9202 - loss: 0.6328 - val_sparse_categorical_accuracy: 0.8394 - val_loss: 0.7052
# Epoch 11/16
# 28/28 [==============================] - 7s 265ms/step - sparse_categorical_accuracy: 0.9230 - loss: 0.6300 - val_sparse_categorical_accuracy: 0.8355 - val_loss: 0.7128
# Epoch 12/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.9246 - loss: 0.6278 - val_sparse_categorical_accuracy: 0.8456 - val_loss: 0.6998
# Epoch 13/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.9356 - loss: 0.6166 - val_sparse_categorical_accuracy: 0.8478 - val_loss: 0.6994
# Epoch 14/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9405 - loss: 0.6119 - val_sparse_categorical_accuracy: 0.8370 - val_loss: 0.7090
# Epoch 15/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9454 - loss: 0.6067 - val_sparse_categorical_accuracy: 0.8454 - val_loss: 0.7017
# Epoch 16/16
# 28/28 [==============================] - 10s 351ms/step - sparse_categorical_accuracy: 0.9486 - loss: 0.6033 - val_sparse_categorical_accuracy: 0.8550 - val_loss: 0.6932
#
# Validating
# 3/3 [==============================] - 8s 3s/step
#
# Inferencing
# 5/5 [==============================] - 11s 2s/step
#
# Fold 2 Accuracy: 0.855
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 3 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 38s 1s/step - sparse_categorical_accuracy: 0.5305 - loss: 1.0090 - val_sparse_categorical_accuracy: 0.6868 - val_loss: 0.8785
# Epoch 2/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.7221 - loss: 0.8324 - val_sparse_categorical_accuracy: 0.7577 - val_loss: 0.7900
# Epoch 3/16
# 28/28 [==============================] - 10s 350ms/step - sparse_categorical_accuracy: 0.7857 - loss: 0.7656 - val_sparse_categorical_accuracy: 0.7849 - val_loss: 0.7628
# Epoch 4/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.8218 - loss: 0.7288 - val_sparse_categorical_accuracy: 0.7980 - val_loss: 0.7469
# Epoch 5/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.8514 - loss: 0.7019 - val_sparse_categorical_accuracy: 0.8037 - val_loss: 0.7394
# Epoch 6/16
# 28/28 [==============================] - 10s 345ms/step - sparse_categorical_accuracy: 0.8654 - loss: 0.6855 - val_sparse_categorical_accuracy: 0.8184 - val_loss: 0.7264
# Epoch 7/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.8906 - loss: 0.6642 - val_sparse_categorical_accuracy: 0.8217 - val_loss: 0.7228
# Epoch 8/16
# 28/28 [==============================] - 7s 266ms/step - sparse_categorical_accuracy: 0.8982 - loss: 0.6548 - val_sparse_categorical_accuracy: 0.8192 - val_loss: 0.7244
# Epoch 9/16
# 28/28 [==============================] - 9s 338ms/step - sparse_categorical_accuracy: 0.9139 - loss: 0.6394 - val_sparse_categorical_accuracy: 0.8290 - val_loss: 0.7156
# Epoch 10/16
# 28/28 [==============================] - 10s 351ms/step - sparse_categorical_accuracy: 0.9211 - loss: 0.6310 - val_sparse_categorical_accuracy: 0.8308 - val_loss: 0.7126
# Epoch 11/16
# 28/28 [==============================] - 10s 341ms/step - sparse_categorical_accuracy: 0.9295 - loss: 0.6240 - val_sparse_categorical_accuracy: 0.8394 - val_loss: 0.7073
# Epoch 12/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9358 - loss: 0.6173 - val_sparse_categorical_accuracy: 0.8311 - val_loss: 0.7166
# Epoch 13/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9398 - loss: 0.6127 - val_sparse_categorical_accuracy: 0.8353 - val_loss: 0.7085
# Epoch 14/16
# 28/28 [==============================] - 10s 345ms/step - sparse_categorical_accuracy: 0.9432 - loss: 0.6086 - val_sparse_categorical_accuracy: 0.8456 - val_loss: 0.7012
# Epoch 15/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9498 - loss: 0.6029 - val_sparse_categorical_accuracy: 0.8360 - val_loss: 0.7100
# Epoch 16/16
# 28/28 [==============================] - 7s 266ms/step - sparse_categorical_accuracy: 0.9524 - loss: 0.5997 - val_sparse_categorical_accuracy: 0.8447 - val_loss: 0.7023
#
# Validating
# 3/3 [==============================] - 8s 3s/step
#
# Inferencing
# 5/5 [==============================] - 11s 2s/step
#
# Fold 3 Accuracy: 0.8456
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 4 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 58s 2s/step - sparse_categorical_accuracy: 0.5076 - loss: 1.0284 - val_sparse_categorical_accuracy: 0.6134 - val_loss: 0.9365
# Epoch 2/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.7034 - loss: 0.8512 - val_sparse_categorical_accuracy: 0.7548 - val_loss: 0.7921
# Epoch 3/16
# 28/28 [==============================] - 10s 350ms/step - sparse_categorical_accuracy: 0.7787 - loss: 0.7709 - val_sparse_categorical_accuracy: 0.7750 - val_loss: 0.7682
# Epoch 4/16
# 28/28 [==============================] - 10s 352ms/step - sparse_categorical_accuracy: 0.8214 - loss: 0.7295 - val_sparse_categorical_accuracy: 0.7993 - val_loss: 0.7461
# Epoch 5/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.8475 - loss: 0.7044 - val_sparse_categorical_accuracy: 0.8104 - val_loss: 0.7320
# Epoch 6/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.8724 - loss: 0.6807 - val_sparse_categorical_accuracy: 0.8230 - val_loss: 0.7217
# Epoch 7/16
# 28/28 [==============================] - 10s 352ms/step - sparse_categorical_accuracy: 0.8862 - loss: 0.6669 - val_sparse_categorical_accuracy: 0.8314 - val_loss: 0.7142
# Epoch 8/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.9020 - loss: 0.6520 - val_sparse_categorical_accuracy: 0.8374 - val_loss: 0.7078
# Epoch 9/16
# 28/28 [==============================] - 10s 351ms/step - sparse_categorical_accuracy: 0.9122 - loss: 0.6410 - val_sparse_categorical_accuracy: 0.8378 - val_loss: 0.7068
# Epoch 10/16
# 28/28 [==============================] - 8s 268ms/step - sparse_categorical_accuracy: 0.9219 - loss: 0.6317 - val_sparse_categorical_accuracy: 0.8220 - val_loss: 0.7244
# Epoch 11/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.9287 - loss: 0.6246 - val_sparse_categorical_accuracy: 0.8531 - val_loss: 0.6935
# Epoch 12/16
# 28/28 [==============================] - 7s 266ms/step - sparse_categorical_accuracy: 0.9355 - loss: 0.6171 - val_sparse_categorical_accuracy: 0.8472 - val_loss: 0.6995
# Epoch 13/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.9422 - loss: 0.6106 - val_sparse_categorical_accuracy: 0.8596 - val_loss: 0.6896
# Epoch 14/16
# 28/28 [==============================] - 8s 269ms/step - sparse_categorical_accuracy: 0.9459 - loss: 0.6059 - val_sparse_categorical_accuracy: 0.8557 - val_loss: 0.6920
# Epoch 15/16
# 28/28 [==============================] - 8s 289ms/step - sparse_categorical_accuracy: 0.9481 - loss: 0.6050 - val_sparse_categorical_accuracy: 0.8594 - val_loss: 0.6884
# Epoch 16/16
# 28/28 [==============================] - 8s 268ms/step - sparse_categorical_accuracy: 0.9543 - loss: 0.5990 - val_sparse_categorical_accuracy: 0.8512 - val_loss: 0.6949
#
# Validating
# 3/3 [==============================] - 8s 3s/step
#
# Inferencing
# 5/5 [==============================] - 11s 2s/step
#
# Fold 4 Accuracy: 0.8596
#
#
# CV Mean Accuracy: 0.8557
# CV StdDev Accuracy: 0.0065

# %%
# Model: Bert Base Uncased
# config_3 = Configuration("bert-base-uncased", max_length = 84, batch_size = 64, epochs = 16, train_splits = 4)
# preds_train_3, preds_test_3 = run_model(config_3)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=536063208.0, style=ProgressStyle(descri…
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 84)]              0
# _________________________________________________________________
# tf_bert_model (TFBertModel)  ((None, 84, 768), (None,  109482240
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 768)]             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 2307
# =================================================================
# Total params: 109,484,547
# Trainable params: 109,484,547
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ###################
# ##### Fold: 1 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 57s 2s/step - sparse_categorical_accuracy: 0.4877 - loss: 1.0388 - val_sparse_categorical_accuracy: 0.6484 - val_loss: 0.9174
# Epoch 2/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.7044 - loss: 0.8563 - val_sparse_categorical_accuracy: 0.7622 - val_loss: 0.7929
# Epoch 3/16
# 28/28 [==============================] - 10s 343ms/step - sparse_categorical_accuracy: 0.7727 - loss: 0.7791 - val_sparse_categorical_accuracy: 0.7931 - val_loss: 0.7571
# Epoch 4/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.8138 - loss: 0.7389 - val_sparse_categorical_accuracy: 0.8016 - val_loss: 0.7458
# Epoch 5/16
# 28/28 [==============================] - 10s 345ms/step - sparse_categorical_accuracy: 0.8436 - loss: 0.7115 - val_sparse_categorical_accuracy: 0.8174 - val_loss: 0.7298
# Epoch 6/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.8639 - loss: 0.6897 - val_sparse_categorical_accuracy: 0.8257 - val_loss: 0.7206
# Epoch 7/16
# 28/28 [==============================] - 10s 353ms/step - sparse_categorical_accuracy: 0.8783 - loss: 0.6751 - val_sparse_categorical_accuracy: 0.8349 - val_loss: 0.7121
# Epoch 8/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.8934 - loss: 0.6601 - val_sparse_categorical_accuracy: 0.8341 - val_loss: 0.7130
# Epoch 9/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.9074 - loss: 0.6466 - val_sparse_categorical_accuracy: 0.8439 - val_loss: 0.7035
# Epoch 10/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9146 - loss: 0.6389 - val_sparse_categorical_accuracy: 0.8411 - val_loss: 0.7038
# Epoch 11/16
# 28/28 [==============================] - 8s 270ms/step - sparse_categorical_accuracy: 0.9256 - loss: 0.6285 - val_sparse_categorical_accuracy: 0.8439 - val_loss: 0.7012
# Epoch 12/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.9308 - loss: 0.6221 - val_sparse_categorical_accuracy: 0.8476 - val_loss: 0.6986
# Epoch 13/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.9356 - loss: 0.6169 - val_sparse_categorical_accuracy: 0.8492 - val_loss: 0.6987
# Epoch 14/16
# 28/28 [==============================] - 10s 353ms/step - sparse_categorical_accuracy: 0.9434 - loss: 0.6090 - val_sparse_categorical_accuracy: 0.8521 - val_loss: 0.6952
# Epoch 15/16
# 28/28 [==============================] - 10s 342ms/step - sparse_categorical_accuracy: 0.9479 - loss: 0.6054 - val_sparse_categorical_accuracy: 0.8529 - val_loss: 0.6942
# Epoch 16/16
# 28/28 [==============================] - 7s 265ms/step - sparse_categorical_accuracy: 0.9512 - loss: 0.6007 - val_sparse_categorical_accuracy: 0.8515 - val_loss: 0.6962
#
# Validating
# 3/3 [==============================] - 17s 6s/step
#
# Inferencing
# 5/5 [==============================] - 17s 3s/step
#
# Fold 1 Accuracy: 0.8529
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 2 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 60s 2s/step - sparse_categorical_accuracy: 0.5171 - loss: 1.0176 - val_sparse_categorical_accuracy: 0.6846 - val_loss: 0.8783
# Epoch 2/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.7243 - loss: 0.8312 - val_sparse_categorical_accuracy: 0.7583 - val_loss: 0.7866
# Epoch 3/16
# 28/28 [==============================] - 10s 344ms/step - sparse_categorical_accuracy: 0.7910 - loss: 0.7609 - val_sparse_categorical_accuracy: 0.7992 - val_loss: 0.7495
# Epoch 4/16
# 28/28 [==============================] - 10s 343ms/step - sparse_categorical_accuracy: 0.8246 - loss: 0.7277 - val_sparse_categorical_accuracy: 0.8065 - val_loss: 0.7409
# Epoch 5/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.8474 - loss: 0.7047 - val_sparse_categorical_accuracy: 0.8192 - val_loss: 0.7275
# Epoch 6/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.8703 - loss: 0.6831 - val_sparse_categorical_accuracy: 0.8253 - val_loss: 0.7215
# Epoch 7/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.8823 - loss: 0.6699 - val_sparse_categorical_accuracy: 0.8239 - val_loss: 0.7225
# Epoch 8/16
# 28/28 [==============================] - 10s 342ms/step - sparse_categorical_accuracy: 0.8993 - loss: 0.6539 - val_sparse_categorical_accuracy: 0.8341 - val_loss: 0.7134
# Epoch 9/16
# 28/28 [==============================] - 10s 346ms/step - sparse_categorical_accuracy: 0.9121 - loss: 0.6415 - val_sparse_categorical_accuracy: 0.8421 - val_loss: 0.7065
# Epoch 10/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.9185 - loss: 0.6346 - val_sparse_categorical_accuracy: 0.8458 - val_loss: 0.7014
# Epoch 11/16
# 28/28 [==============================] - 10s 342ms/step - sparse_categorical_accuracy: 0.9261 - loss: 0.6264 - val_sparse_categorical_accuracy: 0.8478 - val_loss: 0.6980
# Epoch 12/16
# 28/28 [==============================] - 7s 265ms/step - sparse_categorical_accuracy: 0.9335 - loss: 0.6198 - val_sparse_categorical_accuracy: 0.8462 - val_loss: 0.7017
# Epoch 13/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.9402 - loss: 0.6123 - val_sparse_categorical_accuracy: 0.8505 - val_loss: 0.6976
# Epoch 14/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.9415 - loss: 0.6112 - val_sparse_categorical_accuracy: 0.8550 - val_loss: 0.6915
# Epoch 15/16
# 28/28 [==============================] - 7s 267ms/step - sparse_categorical_accuracy: 0.9443 - loss: 0.6083 - val_sparse_categorical_accuracy: 0.8523 - val_loss: 0.6948
# Epoch 16/16
# 28/28 [==============================] - 8s 268ms/step - sparse_categorical_accuracy: 0.9503 - loss: 0.6018 - val_sparse_categorical_accuracy: 0.8519 - val_loss: 0.6937
#
# Validating
# 3/3 [==============================] - 8s 3s/step
#
# Inferencing
# 5/5 [==============================] - 11s 2s/step
#
# Fold 2 Accuracy: 0.855
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 3 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 42s 1s/step - sparse_categorical_accuracy: 0.4717 - loss: 1.0457 - val_sparse_categorical_accuracy: 0.6374 - val_loss: 0.9207
# Epoch 2/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.6948 - loss: 0.8617 - val_sparse_categorical_accuracy: 0.7401 - val_loss: 0.8076
# Epoch 3/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.7744 - loss: 0.7767 - val_sparse_categorical_accuracy: 0.7608 - val_loss: 0.7824
# Epoch 4/16
# 28/28 [==============================] - 10s 352ms/step - sparse_categorical_accuracy: 0.8116 - loss: 0.7407 - val_sparse_categorical_accuracy: 0.7982 - val_loss: 0.7490
# Epoch 5/16
# 28/28 [==============================] - 10s 356ms/step - sparse_categorical_accuracy: 0.8382 - loss: 0.7129 - val_sparse_categorical_accuracy: 0.8074 - val_loss: 0.7389
# Epoch 6/16
# 28/28 [==============================] - 10s 360ms/step - sparse_categorical_accuracy: 0.8547 - loss: 0.6960 - val_sparse_categorical_accuracy: 0.8155 - val_loss: 0.7316
# Epoch 7/16
# 28/28 [==============================] - 10s 362ms/step - sparse_categorical_accuracy: 0.8782 - loss: 0.6740 - val_sparse_categorical_accuracy: 0.8157 - val_loss: 0.7275
# Epoch 8/16
# 28/28 [==============================] - 11s 375ms/step - sparse_categorical_accuracy: 0.8910 - loss: 0.6607 - val_sparse_categorical_accuracy: 0.8306 - val_loss: 0.7177
# Epoch 9/16
# 28/28 [==============================] - 10s 356ms/step - sparse_categorical_accuracy: 0.9039 - loss: 0.6491 - val_sparse_categorical_accuracy: 0.8337 - val_loss: 0.7139
# Epoch 10/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.9148 - loss: 0.6382 - val_sparse_categorical_accuracy: 0.8370 - val_loss: 0.7112
# Epoch 11/16
# 28/28 [==============================] - 8s 271ms/step - sparse_categorical_accuracy: 0.9200 - loss: 0.6331 - val_sparse_categorical_accuracy: 0.8284 - val_loss: 0.7172
# Epoch 12/16
# 28/28 [==============================] - 8s 268ms/step - sparse_categorical_accuracy: 0.9263 - loss: 0.6260 - val_sparse_categorical_accuracy: 0.8259 - val_loss: 0.7200
# Epoch 13/16
# 28/28 [==============================] - 10s 367ms/step - sparse_categorical_accuracy: 0.9337 - loss: 0.6187 - val_sparse_categorical_accuracy: 0.8451 - val_loss: 0.7031
# Epoch 14/16
# 28/28 [==============================] - 8s 269ms/step - sparse_categorical_accuracy: 0.9411 - loss: 0.6114 - val_sparse_categorical_accuracy: 0.8382 - val_loss: 0.7081
# Epoch 15/16
# 28/28 [==============================] - 8s 269ms/step - sparse_categorical_accuracy: 0.9445 - loss: 0.6072 - val_sparse_categorical_accuracy: 0.8439 - val_loss: 0.7030
# Epoch 16/16
# 28/28 [==============================] - 8s 269ms/step - sparse_categorical_accuracy: 0.9492 - loss: 0.6032 - val_sparse_categorical_accuracy: 0.8384 - val_loss: 0.7086
#
# Validating
# 3/3 [==============================] - 9s 3s/step
#
# Inferencing
# 5/5 [==============================] - 11s 2s/step
#
# Fold 3 Accuracy: 0.8451
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 4 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 42s 1s/step - sparse_categorical_accuracy: 0.4882 - loss: 1.0328 - val_sparse_categorical_accuracy: 0.6559 - val_loss: 0.9061
# Epoch 2/16
# 28/28 [==============================] - 10s 353ms/step - sparse_categorical_accuracy: 0.7033 - loss: 0.8556 - val_sparse_categorical_accuracy: 0.7540 - val_loss: 0.7999
# Epoch 3/16
# 28/28 [==============================] - 10s 359ms/step - sparse_categorical_accuracy: 0.7752 - loss: 0.7778 - val_sparse_categorical_accuracy: 0.7838 - val_loss: 0.7619
# Epoch 4/16
# 28/28 [==============================] - 10s 349ms/step - sparse_categorical_accuracy: 0.8158 - loss: 0.7369 - val_sparse_categorical_accuracy: 0.8087 - val_loss: 0.7392
# Epoch 5/16
# 28/28 [==============================] - 10s 347ms/step - sparse_categorical_accuracy: 0.8417 - loss: 0.7121 - val_sparse_categorical_accuracy: 0.8218 - val_loss: 0.7256
# Epoch 6/16
# 28/28 [==============================] - 10s 348ms/step - sparse_categorical_accuracy: 0.8668 - loss: 0.6879 - val_sparse_categorical_accuracy: 0.8286 - val_loss: 0.7174
# Epoch 7/16
# 28/28 [==============================] - 10s 351ms/step - sparse_categorical_accuracy: 0.8807 - loss: 0.6732 - val_sparse_categorical_accuracy: 0.8288 - val_loss: 0.7166
# Epoch 8/16
# 28/28 [==============================] - 10s 359ms/step - sparse_categorical_accuracy: 0.8926 - loss: 0.6602 - val_sparse_categorical_accuracy: 0.8435 - val_loss: 0.7045
# Epoch 9/16
# 28/28 [==============================] - 10s 350ms/step - sparse_categorical_accuracy: 0.9069 - loss: 0.6477 - val_sparse_categorical_accuracy: 0.8494 - val_loss: 0.6972
# Epoch 10/16
# 28/28 [==============================] - 8s 268ms/step - sparse_categorical_accuracy: 0.9185 - loss: 0.6359 - val_sparse_categorical_accuracy: 0.8488 - val_loss: 0.6979
# Epoch 11/16
# 28/28 [==============================] - 10s 351ms/step - sparse_categorical_accuracy: 0.9236 - loss: 0.6304 - val_sparse_categorical_accuracy: 0.8506 - val_loss: 0.6957
# Epoch 12/16
# 28/28 [==============================] - 10s 353ms/step - sparse_categorical_accuracy: 0.9325 - loss: 0.6207 - val_sparse_categorical_accuracy: 0.8541 - val_loss: 0.6941
# Epoch 13/16
# 28/28 [==============================] - 10s 352ms/step - sparse_categorical_accuracy: 0.9373 - loss: 0.6161 - val_sparse_categorical_accuracy: 0.8623 - val_loss: 0.6868
# Epoch 14/16
# 28/28 [==============================] - 8s 272ms/step - sparse_categorical_accuracy: 0.9394 - loss: 0.6130 - val_sparse_categorical_accuracy: 0.8472 - val_loss: 0.7022
# Epoch 15/16
# 28/28 [==============================] - 8s 269ms/step - sparse_categorical_accuracy: 0.9470 - loss: 0.6068 - val_sparse_categorical_accuracy: 0.8553 - val_loss: 0.6914
# Epoch 16/16
# 28/28 [==============================] - 8s 271ms/step - sparse_categorical_accuracy: 0.9521 - loss: 0.6004 - val_sparse_categorical_accuracy: 0.8537 - val_loss: 0.6920
#
# Validating
# 3/3 [==============================] - 9s 3s/step
#
# Inferencing
# 5/5 [==============================] - 11s 2s/step
#
# Fold 4 Accuracy: 0.8623
#
#
# CV Mean Accuracy: 0.8538
# CV StdDev Accuracy: 0.0061

# %%
# Model: Bert Large Cased
# config_4 = Configuration("bert-large-cased", max_length = 84, batch_size = 64, epochs = 16, train_splits = 4)
# preds_train_4, preds_test_4 = run_model(config_4)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=625.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1460062736.0, style=ProgressStyle(descr…
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 84)]              0
# _________________________________________________________________
# tf_bert_model (TFBertModel)  ((None, 84, 1024), (None, 333579264
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 1024)]            0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 3075
# =================================================================
# Total params: 333,582,339
# Trainable params: 333,582,339
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ###################
# ##### Fold: 1 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 106s 4s/step - sparse_categorical_accuracy: 0.4948 - loss: 1.0305 - val_sparse_categorical_accuracy: 0.6429 - val_loss: 0.9227
# Epoch 2/16
# 28/28 [==============================] - 27s 955ms/step - sparse_categorical_accuracy: 0.7153 - loss: 0.8372 - val_sparse_categorical_accuracy: 0.7610 - val_loss: 0.7835
# Epoch 3/16
# 28/28 [==============================] - 27s 970ms/step - sparse_categorical_accuracy: 0.7921 - loss: 0.7563 - val_sparse_categorical_accuracy: 0.8037 - val_loss: 0.7418
# Epoch 4/16
# 28/28 [==============================] - 27s 956ms/step - sparse_categorical_accuracy: 0.8413 - loss: 0.7111 - val_sparse_categorical_accuracy: 0.8165 - val_loss: 0.7284
# Epoch 5/16
# 28/28 [==============================] - 26s 939ms/step - sparse_categorical_accuracy: 0.8562 - loss: 0.6948 - val_sparse_categorical_accuracy: 0.8198 - val_loss: 0.7259
# Epoch 6/16
# 28/28 [==============================] - 27s 966ms/step - sparse_categorical_accuracy: 0.8765 - loss: 0.6739 - val_sparse_categorical_accuracy: 0.8370 - val_loss: 0.7090
# Epoch 7/16
# 28/28 [==============================] - 27s 948ms/step - sparse_categorical_accuracy: 0.9051 - loss: 0.6469 - val_sparse_categorical_accuracy: 0.8476 - val_loss: 0.7006
# Epoch 8/16
# 28/28 [==============================] - 27s 959ms/step - sparse_categorical_accuracy: 0.9231 - loss: 0.6305 - val_sparse_categorical_accuracy: 0.8521 - val_loss: 0.6948
# Epoch 9/16
# 28/28 [==============================] - 26s 945ms/step - sparse_categorical_accuracy: 0.9331 - loss: 0.6200 - val_sparse_categorical_accuracy: 0.8560 - val_loss: 0.6937
# Epoch 10/16
# 28/28 [==============================] - 19s 682ms/step - sparse_categorical_accuracy: 0.9434 - loss: 0.6096 - val_sparse_categorical_accuracy: 0.8484 - val_loss: 0.6960
# Epoch 11/16
# 28/28 [==============================] - 26s 944ms/step - sparse_categorical_accuracy: 0.9496 - loss: 0.6031 - val_sparse_categorical_accuracy: 0.8629 - val_loss: 0.6847
# Epoch 12/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9564 - loss: 0.5970 - val_sparse_categorical_accuracy: 0.8617 - val_loss: 0.6861
# Epoch 13/16
# 28/28 [==============================] - 25s 910ms/step - sparse_categorical_accuracy: 0.9595 - loss: 0.5932 - val_sparse_categorical_accuracy: 0.8660 - val_loss: 0.6829
# Epoch 14/16
# 28/28 [==============================] - 19s 677ms/step - sparse_categorical_accuracy: 0.9646 - loss: 0.5883 - val_sparse_categorical_accuracy: 0.8652 - val_loss: 0.6824
# Epoch 15/16
# 28/28 [==============================] - 27s 963ms/step - sparse_categorical_accuracy: 0.9650 - loss: 0.5870 - val_sparse_categorical_accuracy: 0.8672 - val_loss: 0.6823
# Epoch 16/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9648 - loss: 0.5871 - val_sparse_categorical_accuracy: 0.8664 - val_loss: 0.6810
#
# Validating
# 3/3 [==============================] - 33s 11s/step
#
# Inferencing
# 5/5 [==============================] - 30s 6s/step
#
# Fold 1 Accuracy: 0.8672
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 2 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 107s 4s/step - sparse_categorical_accuracy: 0.5815 - loss: 0.9554 - val_sparse_categorical_accuracy: 0.7258 - val_loss: 0.8231
# Epoch 2/16
# 28/28 [==============================] - 26s 930ms/step - sparse_categorical_accuracy: 0.7767 - loss: 0.7730 - val_sparse_categorical_accuracy: 0.7994 - val_loss: 0.7482
# Epoch 3/16
# 28/28 [==============================] - 28s 983ms/step - sparse_categorical_accuracy: 0.8361 - loss: 0.7160 - val_sparse_categorical_accuracy: 0.8286 - val_loss: 0.7185
# Epoch 4/16
# 28/28 [==============================] - 28s 984ms/step - sparse_categorical_accuracy: 0.8659 - loss: 0.6856 - val_sparse_categorical_accuracy: 0.8343 - val_loss: 0.7135
# Epoch 5/16
# 28/28 [==============================] - 27s 953ms/step - sparse_categorical_accuracy: 0.8907 - loss: 0.6605 - val_sparse_categorical_accuracy: 0.8378 - val_loss: 0.7101
# Epoch 6/16
# 28/28 [==============================] - 26s 946ms/step - sparse_categorical_accuracy: 0.9107 - loss: 0.6409 - val_sparse_categorical_accuracy: 0.8441 - val_loss: 0.7008
# Epoch 7/16
# 28/28 [==============================] - 27s 969ms/step - sparse_categorical_accuracy: 0.9252 - loss: 0.6276 - val_sparse_categorical_accuracy: 0.8474 - val_loss: 0.6975
# Epoch 8/16
# 28/28 [==============================] - 27s 955ms/step - sparse_categorical_accuracy: 0.9353 - loss: 0.6183 - val_sparse_categorical_accuracy: 0.8592 - val_loss: 0.6901
# Epoch 9/16
# 28/28 [==============================] - 27s 972ms/step - sparse_categorical_accuracy: 0.9430 - loss: 0.6094 - val_sparse_categorical_accuracy: 0.8603 - val_loss: 0.6888
# Epoch 10/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9543 - loss: 0.5992 - val_sparse_categorical_accuracy: 0.8562 - val_loss: 0.6919
# Epoch 11/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9543 - loss: 0.5980 - val_sparse_categorical_accuracy: 0.8590 - val_loss: 0.6883
# Epoch 12/16
# 28/28 [==============================] - 27s 969ms/step - sparse_categorical_accuracy: 0.9607 - loss: 0.5919 - val_sparse_categorical_accuracy: 0.8635 - val_loss: 0.6848
# Epoch 13/16
# 28/28 [==============================] - 27s 975ms/step - sparse_categorical_accuracy: 0.9615 - loss: 0.5908 - val_sparse_categorical_accuracy: 0.8656 - val_loss: 0.6837
# Epoch 14/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9638 - loss: 0.5886 - val_sparse_categorical_accuracy: 0.8625 - val_loss: 0.6852
# Epoch 15/16
# 28/28 [==============================] - 26s 937ms/step - sparse_categorical_accuracy: 0.9644 - loss: 0.5875 - val_sparse_categorical_accuracy: 0.8662 - val_loss: 0.6814
# Epoch 16/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9668 - loss: 0.5851 - val_sparse_categorical_accuracy: 0.8644 - val_loss: 0.6835
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 2 Accuracy: 0.8662
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 3 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 67s 2s/step - sparse_categorical_accuracy: 0.5856 - loss: 0.9539 - val_sparse_categorical_accuracy: 0.7365 - val_loss: 0.8109
# Epoch 2/16
# 28/28 [==============================] - 27s 981ms/step - sparse_categorical_accuracy: 0.7831 - loss: 0.7679 - val_sparse_categorical_accuracy: 0.7910 - val_loss: 0.7572
# Epoch 3/16
# 28/28 [==============================] - 27s 963ms/step - sparse_categorical_accuracy: 0.8408 - loss: 0.7104 - val_sparse_categorical_accuracy: 0.8106 - val_loss: 0.7339
# Epoch 4/16
# 28/28 [==============================] - 27s 967ms/step - sparse_categorical_accuracy: 0.8731 - loss: 0.6784 - val_sparse_categorical_accuracy: 0.8366 - val_loss: 0.7084
# Epoch 5/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9024 - loss: 0.6520 - val_sparse_categorical_accuracy: 0.8294 - val_loss: 0.7143
# Epoch 6/16
# 28/28 [==============================] - 27s 972ms/step - sparse_categorical_accuracy: 0.9182 - loss: 0.6345 - val_sparse_categorical_accuracy: 0.8505 - val_loss: 0.6970
# Epoch 7/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9300 - loss: 0.6232 - val_sparse_categorical_accuracy: 0.8368 - val_loss: 0.7109
# Epoch 8/16
# 28/28 [==============================] - 27s 968ms/step - sparse_categorical_accuracy: 0.9420 - loss: 0.6115 - val_sparse_categorical_accuracy: 0.8529 - val_loss: 0.6924
# Epoch 9/16
# 28/28 [==============================] - 19s 683ms/step - sparse_categorical_accuracy: 0.9456 - loss: 0.6066 - val_sparse_categorical_accuracy: 0.8496 - val_loss: 0.6964
# Epoch 10/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9555 - loss: 0.5974 - val_sparse_categorical_accuracy: 0.8521 - val_loss: 0.6952
# Epoch 11/16
# 28/28 [==============================] - 27s 971ms/step - sparse_categorical_accuracy: 0.9594 - loss: 0.5926 - val_sparse_categorical_accuracy: 0.8601 - val_loss: 0.6876
# Epoch 12/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9625 - loss: 0.5897 - val_sparse_categorical_accuracy: 0.8556 - val_loss: 0.6928
# Epoch 13/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9650 - loss: 0.5877 - val_sparse_categorical_accuracy: 0.8601 - val_loss: 0.6882
# Epoch 14/16
# 28/28 [==============================] - 27s 968ms/step - sparse_categorical_accuracy: 0.9660 - loss: 0.5860 - val_sparse_categorical_accuracy: 0.8637 - val_loss: 0.6844
# Epoch 15/16
# 28/28 [==============================] - 27s 980ms/step - sparse_categorical_accuracy: 0.9683 - loss: 0.5839 - val_sparse_categorical_accuracy: 0.8648 - val_loss: 0.6829
# Epoch 16/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9706 - loss: 0.5813 - val_sparse_categorical_accuracy: 0.8619 - val_loss: 0.6859
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 3 Accuracy: 0.8648
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 4 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 64s 2s/step - sparse_categorical_accuracy: 0.6096 - loss: 0.9333 - val_sparse_categorical_accuracy: 0.7364 - val_loss: 0.8075
# Epoch 2/16
# 28/28 [==============================] - 27s 976ms/step - sparse_categorical_accuracy: 0.7844 - loss: 0.7661 - val_sparse_categorical_accuracy: 0.7953 - val_loss: 0.7481
# Epoch 3/16
# 28/28 [==============================] - 27s 982ms/step - sparse_categorical_accuracy: 0.8398 - loss: 0.7106 - val_sparse_categorical_accuracy: 0.8190 - val_loss: 0.7251
# Epoch 4/16
# 28/28 [==============================] - 27s 970ms/step - sparse_categorical_accuracy: 0.8686 - loss: 0.6823 - val_sparse_categorical_accuracy: 0.8228 - val_loss: 0.7214
# Epoch 5/16
# 28/28 [==============================] - 27s 956ms/step - sparse_categorical_accuracy: 0.8910 - loss: 0.6612 - val_sparse_categorical_accuracy: 0.8474 - val_loss: 0.6994
# Epoch 6/16
# 28/28 [==============================] - 19s 690ms/step - sparse_categorical_accuracy: 0.9157 - loss: 0.6372 - val_sparse_categorical_accuracy: 0.8465 - val_loss: 0.6969
# Epoch 7/16
# 28/28 [==============================] - 28s 985ms/step - sparse_categorical_accuracy: 0.9242 - loss: 0.6277 - val_sparse_categorical_accuracy: 0.8535 - val_loss: 0.6918
# Epoch 8/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9333 - loss: 0.6195 - val_sparse_categorical_accuracy: 0.8506 - val_loss: 0.6959
# Epoch 9/16
# 28/28 [==============================] - 19s 685ms/step - sparse_categorical_accuracy: 0.9393 - loss: 0.6138 - val_sparse_categorical_accuracy: 0.8302 - val_loss: 0.7153
# Epoch 10/16
# 28/28 [==============================] - 27s 959ms/step - sparse_categorical_accuracy: 0.9485 - loss: 0.6038 - val_sparse_categorical_accuracy: 0.8676 - val_loss: 0.6815
# Epoch 11/16
# 28/28 [==============================] - 27s 973ms/step - sparse_categorical_accuracy: 0.9561 - loss: 0.5967 - val_sparse_categorical_accuracy: 0.8688 - val_loss: 0.6797
# Epoch 12/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9586 - loss: 0.5929 - val_sparse_categorical_accuracy: 0.8584 - val_loss: 0.6872
# Epoch 13/16
# 28/28 [==============================] - 19s 685ms/step - sparse_categorical_accuracy: 0.9601 - loss: 0.5923 - val_sparse_categorical_accuracy: 0.8668 - val_loss: 0.6814
# Epoch 14/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9651 - loss: 0.5871 - val_sparse_categorical_accuracy: 0.8404 - val_loss: 0.7058
# Epoch 15/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.9636 - loss: 0.5888 - val_sparse_categorical_accuracy: 0.8678 - val_loss: 0.6799
# Epoch 16/16
# 28/28 [==============================] - 19s 677ms/step - sparse_categorical_accuracy: 0.9678 - loss: 0.5841 - val_sparse_categorical_accuracy: 0.8606 - val_loss: 0.6859
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 4 Accuracy: 0.8688
#
#
# CV Mean Accuracy: 0.8667
# CV StdDev Accuracy: 0.0015

# %%
# Model: Bert Large Uncased
config_5 = Configuration("bert-large-uncased", max_length = 84, batch_size = 64, epochs = 16, train_splits = 4)
preds_train_5, preds_test_5 = run_model(config_5)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=434.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1472569832.0, style=ProgressStyle(descr…
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 84)]              0
# _________________________________________________________________
# tf_bert_model (TFBertModel)  ((None, 84, 1024), (None, 335141888
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 1024)]            0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 3075
# =================================================================
# Total params: 335,144,963
# Trainable params: 335,144,963
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ###################
# ##### Fold: 1 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 106s 4s/step - sparse_categorical_accuracy: 0.5882 - loss: 0.9522 - val_sparse_categorical_accuracy: 0.7287 - val_loss: 0.8239
# Epoch 2/16
# 28/28 [==============================] - 27s 969ms/step - sparse_categorical_accuracy: 0.7540 - loss: 0.7935 - val_sparse_categorical_accuracy: 0.7904 - val_loss: 0.7558
# Epoch 3/16
# 28/28 [==============================] - 27s 958ms/step - sparse_categorical_accuracy: 0.8087 - loss: 0.7400 - val_sparse_categorical_accuracy: 0.8088 - val_loss: 0.7359
# Epoch 4/16
# 28/28 [==============================] - 27s 966ms/step - sparse_categorical_accuracy: 0.8449 - loss: 0.7053 - val_sparse_categorical_accuracy: 0.8313 - val_loss: 0.7181
# Epoch 5/16
# 28/28 [==============================] - 27s 972ms/step - sparse_categorical_accuracy: 0.8719 - loss: 0.6805 - val_sparse_categorical_accuracy: 0.8431 - val_loss: 0.7045
# Epoch 6/16
# 28/28 [==============================] - 27s 967ms/step - sparse_categorical_accuracy: 0.8945 - loss: 0.6582 - val_sparse_categorical_accuracy: 0.8480 - val_loss: 0.6991
# Epoch 7/16
# 28/28 [==============================] - 27s 960ms/step - sparse_categorical_accuracy: 0.9115 - loss: 0.6420 - val_sparse_categorical_accuracy: 0.8523 - val_loss: 0.6958
# Epoch 8/16
# 28/28 [==============================] - 19s 693ms/step - sparse_categorical_accuracy: 0.9190 - loss: 0.6338 - val_sparse_categorical_accuracy: 0.8464 - val_loss: 0.7017
# Epoch 9/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9298 - loss: 0.6229 - val_sparse_categorical_accuracy: 0.8411 - val_loss: 0.7066
# Epoch 10/16
# 28/28 [==============================] - 27s 979ms/step - sparse_categorical_accuracy: 0.9385 - loss: 0.6145 - val_sparse_categorical_accuracy: 0.8537 - val_loss: 0.6924
# Epoch 11/16
# 28/28 [==============================] - 27s 981ms/step - sparse_categorical_accuracy: 0.9458 - loss: 0.6065 - val_sparse_categorical_accuracy: 0.8658 - val_loss: 0.6833
# Epoch 12/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9478 - loss: 0.6044 - val_sparse_categorical_accuracy: 0.8588 - val_loss: 0.6896
# Epoch 13/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9550 - loss: 0.5971 - val_sparse_categorical_accuracy: 0.8637 - val_loss: 0.6831
# Epoch 14/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9600 - loss: 0.5923 - val_sparse_categorical_accuracy: 0.8605 - val_loss: 0.6859
# Epoch 15/16
# 28/28 [==============================] - 27s 979ms/step - sparse_categorical_accuracy: 0.9603 - loss: 0.5918 - val_sparse_categorical_accuracy: 0.8678 - val_loss: 0.6811
# Epoch 16/16
# 28/28 [==============================] - 19s 683ms/step - sparse_categorical_accuracy: 0.9633 - loss: 0.5888 - val_sparse_categorical_accuracy: 0.8650 - val_loss: 0.6820
#
# Validating
# 3/3 [==============================] - 33s 11s/step
#
# Inferencing
# 5/5 [==============================] - 30s 6s/step
#
# Fold 1 Accuracy: 0.8678
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 2 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 106s 4s/step - sparse_categorical_accuracy: 0.5642 - loss: 0.9683 - val_sparse_categorical_accuracy: 0.7238 - val_loss: 0.8300
# Epoch 2/16
# 28/28 [==============================] - 28s 987ms/step - sparse_categorical_accuracy: 0.7478 - loss: 0.8020 - val_sparse_categorical_accuracy: 0.7900 - val_loss: 0.7594
# Epoch 3/16
# 28/28 [==============================] - 33s 1s/step - sparse_categorical_accuracy: 0.8060 - loss: 0.7425 - val_sparse_categorical_accuracy: 0.8112 - val_loss: 0.7330
# Epoch 4/16
# 28/28 [==============================] - 27s 976ms/step - sparse_categorical_accuracy: 0.8438 - loss: 0.7065 - val_sparse_categorical_accuracy: 0.8235 - val_loss: 0.7240
# Epoch 5/16
# 28/28 [==============================] - 27s 967ms/step - sparse_categorical_accuracy: 0.8677 - loss: 0.6838 - val_sparse_categorical_accuracy: 0.8331 - val_loss: 0.7115
# Epoch 6/16
# 28/28 [==============================] - 27s 972ms/step - sparse_categorical_accuracy: 0.8833 - loss: 0.6675 - val_sparse_categorical_accuracy: 0.8449 - val_loss: 0.7032
# Epoch 7/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9050 - loss: 0.6471 - val_sparse_categorical_accuracy: 0.8396 - val_loss: 0.7067
# Epoch 8/16
# 28/28 [==============================] - 28s 989ms/step - sparse_categorical_accuracy: 0.9153 - loss: 0.6366 - val_sparse_categorical_accuracy: 0.8454 - val_loss: 0.7021
# Epoch 9/16
# 28/28 [==============================] - 19s 685ms/step - sparse_categorical_accuracy: 0.9245 - loss: 0.6277 - val_sparse_categorical_accuracy: 0.8302 - val_loss: 0.7153
# Epoch 10/16
# 28/28 [==============================] - 28s 984ms/step - sparse_categorical_accuracy: 0.9291 - loss: 0.6237 - val_sparse_categorical_accuracy: 0.8599 - val_loss: 0.6878
# Epoch 11/16
# 28/28 [==============================] - 19s 683ms/step - sparse_categorical_accuracy: 0.9318 - loss: 0.6197 - val_sparse_categorical_accuracy: 0.8470 - val_loss: 0.6997
# Epoch 12/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9415 - loss: 0.6104 - val_sparse_categorical_accuracy: 0.8507 - val_loss: 0.6956
# Epoch 13/16
# 28/28 [==============================] - 19s 678ms/step - sparse_categorical_accuracy: 0.9476 - loss: 0.6043 - val_sparse_categorical_accuracy: 0.8537 - val_loss: 0.6932
# Epoch 14/16
# 28/28 [==============================] - 19s 683ms/step - sparse_categorical_accuracy: 0.9532 - loss: 0.5989 - val_sparse_categorical_accuracy: 0.8527 - val_loss: 0.6951
# Epoch 15/16
# 28/28 [==============================] - 19s 678ms/step - sparse_categorical_accuracy: 0.9549 - loss: 0.5977 - val_sparse_categorical_accuracy: 0.8578 - val_loss: 0.6897
# Epoch 16/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9575 - loss: 0.5943 - val_sparse_categorical_accuracy: 0.8470 - val_loss: 0.7004
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 2 Accuracy: 0.8599
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 3 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 66s 2s/step - sparse_categorical_accuracy: 0.5215 - loss: 1.0142 - val_sparse_categorical_accuracy: 0.6564 - val_loss: 0.8989
# Epoch 2/16
# 28/28 [==============================] - 27s 977ms/step - sparse_categorical_accuracy: 0.7079 - loss: 0.8434 - val_sparse_categorical_accuracy: 0.7551 - val_loss: 0.7941
# Epoch 3/16
# 28/28 [==============================] - 27s 970ms/step - sparse_categorical_accuracy: 0.7859 - loss: 0.7646 - val_sparse_categorical_accuracy: 0.7920 - val_loss: 0.7530
# Epoch 4/16
# 28/28 [==============================] - 27s 962ms/step - sparse_categorical_accuracy: 0.8253 - loss: 0.7251 - val_sparse_categorical_accuracy: 0.7943 - val_loss: 0.7503
# Epoch 5/16
# 28/28 [==============================] - 19s 679ms/step - sparse_categorical_accuracy: 0.8477 - loss: 0.7030 - val_sparse_categorical_accuracy: 0.7933 - val_loss: 0.7540
# Epoch 6/16
# 28/28 [==============================] - 28s 985ms/step - sparse_categorical_accuracy: 0.8634 - loss: 0.6876 - val_sparse_categorical_accuracy: 0.8006 - val_loss: 0.7443
# Epoch 7/16
# 28/28 [==============================] - 27s 973ms/step - sparse_categorical_accuracy: 0.8866 - loss: 0.6645 - val_sparse_categorical_accuracy: 0.8210 - val_loss: 0.7246
# Epoch 8/16
# 28/28 [==============================] - 27s 970ms/step - sparse_categorical_accuracy: 0.9037 - loss: 0.6494 - val_sparse_categorical_accuracy: 0.8360 - val_loss: 0.7114
# Epoch 9/16
# 28/28 [==============================] - 28s 988ms/step - sparse_categorical_accuracy: 0.9157 - loss: 0.6379 - val_sparse_categorical_accuracy: 0.8368 - val_loss: 0.7092
# Epoch 10/16
# 28/28 [==============================] - 28s 991ms/step - sparse_categorical_accuracy: 0.9246 - loss: 0.6274 - val_sparse_categorical_accuracy: 0.8411 - val_loss: 0.7037
# Epoch 11/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9342 - loss: 0.6188 - val_sparse_categorical_accuracy: 0.8351 - val_loss: 0.7105
# Epoch 12/16
# 28/28 [==============================] - 19s 682ms/step - sparse_categorical_accuracy: 0.9415 - loss: 0.6115 - val_sparse_categorical_accuracy: 0.8404 - val_loss: 0.7057
# Epoch 13/16
# 28/28 [==============================] - 26s 929ms/step - sparse_categorical_accuracy: 0.9455 - loss: 0.6066 - val_sparse_categorical_accuracy: 0.8458 - val_loss: 0.7002
# Epoch 14/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9516 - loss: 0.6007 - val_sparse_categorical_accuracy: 0.8454 - val_loss: 0.7012
# Epoch 15/16
# 28/28 [==============================] - 19s 680ms/step - sparse_categorical_accuracy: 0.9548 - loss: 0.5982 - val_sparse_categorical_accuracy: 0.8439 - val_loss: 0.7027
# Epoch 16/16
# 28/28 [==============================] - 27s 972ms/step - sparse_categorical_accuracy: 0.9588 - loss: 0.5937 - val_sparse_categorical_accuracy: 0.8501 - val_loss: 0.6975
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 3 Accuracy: 0.8501
#
# Connecting to TPU
# Running on TPU grpc://10.0.0.2:8470
# Initializing TPU
# TPU initialized
# REPLICAS: 8
#
#
# ###################
# ##### Fold: 4 #####
# ###################
#
# Tokenizing
#
# Training
# Epoch 1/16
# 28/28 [==============================] - 66s 2s/step - sparse_categorical_accuracy: 0.5700 - loss: 0.9702 - val_sparse_categorical_accuracy: 0.7286 - val_loss: 0.8237
# Epoch 2/16
# 28/28 [==============================] - 27s 947ms/step - sparse_categorical_accuracy: 0.7580 - loss: 0.7927 - val_sparse_categorical_accuracy: 0.7932 - val_loss: 0.7545
# Epoch 3/16
# 28/28 [==============================] - 28s 991ms/step - sparse_categorical_accuracy: 0.8132 - loss: 0.7358 - val_sparse_categorical_accuracy: 0.8051 - val_loss: 0.7385
# Epoch 4/16
# 28/28 [==============================] - 27s 977ms/step - sparse_categorical_accuracy: 0.8467 - loss: 0.7040 - val_sparse_categorical_accuracy: 0.8320 - val_loss: 0.7173
# Epoch 5/16
# 28/28 [==============================] - 27s 982ms/step - sparse_categorical_accuracy: 0.8750 - loss: 0.6762 - val_sparse_categorical_accuracy: 0.8443 - val_loss: 0.7041
# Epoch 6/16
# 28/28 [==============================] - 27s 978ms/step - sparse_categorical_accuracy: 0.8938 - loss: 0.6585 - val_sparse_categorical_accuracy: 0.8461 - val_loss: 0.7012
# Epoch 7/16
# 28/28 [==============================] - 28s 987ms/step - sparse_categorical_accuracy: 0.9033 - loss: 0.6487 - val_sparse_categorical_accuracy: 0.8472 - val_loss: 0.7004
# Epoch 8/16
# 28/28 [==============================] - 27s 967ms/step - sparse_categorical_accuracy: 0.9189 - loss: 0.6345 - val_sparse_categorical_accuracy: 0.8559 - val_loss: 0.6915
# Epoch 9/16
# 28/28 [==============================] - 28s 985ms/step - sparse_categorical_accuracy: 0.9304 - loss: 0.6225 - val_sparse_categorical_accuracy: 0.8586 - val_loss: 0.6902
# Epoch 10/16
# 28/28 [==============================] - 19s 682ms/step - sparse_categorical_accuracy: 0.9361 - loss: 0.6162 - val_sparse_categorical_accuracy: 0.8527 - val_loss: 0.6954
# Epoch 11/16
# 28/28 [==============================] - 19s 685ms/step - sparse_categorical_accuracy: 0.9420 - loss: 0.6100 - val_sparse_categorical_accuracy: 0.8586 - val_loss: 0.6913
# Epoch 12/16
# 28/28 [==============================] - 27s 981ms/step - sparse_categorical_accuracy: 0.9432 - loss: 0.6085 - val_sparse_categorical_accuracy: 0.8606 - val_loss: 0.6855
# Epoch 13/16
# 28/28 [==============================] - 27s 973ms/step - sparse_categorical_accuracy: 0.9517 - loss: 0.6008 - val_sparse_categorical_accuracy: 0.8617 - val_loss: 0.6847
# Epoch 14/16
# 28/28 [==============================] - 27s 979ms/step - sparse_categorical_accuracy: 0.9543 - loss: 0.5980 - val_sparse_categorical_accuracy: 0.8660 - val_loss: 0.6837
# Epoch 15/16
# 28/28 [==============================] - 19s 681ms/step - sparse_categorical_accuracy: 0.9472 - loss: 0.6043 - val_sparse_categorical_accuracy: 0.8608 - val_loss: 0.6863
# Epoch 16/16
# 28/28 [==============================] - 19s 684ms/step - sparse_categorical_accuracy: 0.9534 - loss: 0.5988 - val_sparse_categorical_accuracy: 0.8545 - val_loss: 0.6922
#
# Validating
# 3/3 [==============================] - 14s 5s/step
#
# Inferencing
# 5/5 [==============================] - 16s 3s/step
#
# Fold 4 Accuracy: 0.866
#
#
# CV Mean Accuracy: 0.8609
# CV StdDev Accuracy: 0.0069
